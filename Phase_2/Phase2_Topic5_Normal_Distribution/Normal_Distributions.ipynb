# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:#5642C5;
#            font-size:200%;
#            font-family:Arial;letter-spacing:0.5px">
#
# <p width = 20%, style="padding: 10px;
#               color:white;">
# Normal Distribution
#
# </p>
# </div>
#
# DS-NTL-010824
# <p>Phase 3 <p>
# <br>
# <br>
#
# <div align = "right">
# <img src="images/flatiron-school-logo.png" align = "right" width="200"/>
# </div>

# %% [markdown]
# # Objectives

# %% [markdown]
# * Describe the normal distribution
# * Calculate $z$-scores from a normal distribution through standardization
# * Describe the normal distribution's Empirical Rule

# %%
import pandas as pd
from scipy import stats
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline

# %% [markdown]
# # Normal Distribution

# %% [markdown]
# We'll find that the **normal distribution** or **normal curve** or **bell curve** (it has many names) is a very common distribution and it's very useful to us in statistics.

# %% [markdown]
# ![](images/normal_curve_animation.gif)

# %% [markdown]
# ## Why a Normal Distribution?

# %% [markdown]
# Turns out the normal distribution describes many phenomena. Think of anything that has a typical range:
#
# - human body temperatures
# - sizes of elephants
# - sizes of stars
# - populations of cities
# - IQ
# - heart rate

# %% [markdown]
# Among human beings, 98.6 degrees Fahrenheit is an _average_ body temperature. Many folks' temperatures won't measure _exactly_ 98.6 degrees, but most measurements will be _close_. It is much more common to have a body temperature close to 98.6 (whether slightly more or slightly less) than it is to have a body temperature far from 98.6 (whether significantly more or significantly less). This is a hallmark of a normally distributed variable.

# %%
fig, ax = plt.subplots()

mu = 0
sigma = 1
# This defines the points along the x-axis
x = np.linspace(
        stats.norm(mu,sigma).ppf(0.01), # Start plotting here
        stats.norm(mu,sigma).ppf(0.99), # End plotting here
        100                             # Number of points
)
# The values as at x given by the normal curve (with mu & sigma)
y = stats.norm(mu,sigma).pdf(x)
ax.plot(x, y,'r-');

# %% [markdown]
# The Standard Normal Distribution, also known as a Gaussian distribution, is special not only because it shows up EVERYWHERE but also because it's symmetric (mean == median == mode)

# %% [markdown]
# ### Normal PDF
#
# If you're curious about how we can mathematically define a normal curve, we give this below. (Don't worry, you don't need to recall the mathematical definition).
#
# <details>
#
# $\Large f(x) = \frac{1}{\sqrt{2\pi\sigma^2}}e^{\frac{-(x - \mu)^2}{2\sigma^2}}$
#
# This might look complicated at first, but what you should focus on is that there are really on two parameters that determine $f(x)$ given $x$
# </details>

# %% [markdown]
# ## Standard Normal Distribution

# %% [markdown]
# A special normal distribution called the **standard normal distribution** has a mean of 0 and variance of 1. This is also known as a z distribution.

# %% [markdown]
# Since we know that the shape of a normal distribution changes based on its mean and variance, we'll typically convert or **standardize** our normal distribution to the standard normal distribution.

# %% [markdown]
# We simply subtract the mean $\mu$ from each value and then divide by the standard deviation $\sigma$:
#
# $$\frac{x - \mu}{\sigma}$$
#
# We call this process **standardization**.

# %% [markdown]
# ![norm_to_z](images/norm_to_z.png)

# %%
# Let's transform the normal distribution centered on 5
# with a standard deviation of 2 into a standard normal

# Generating our data
normal_dist = np.random.normal(loc=5, scale=2, size=1000)

np.mean(normal_dist)
# Out:
# 5.056636386162126

# %%
# Here, let's standardize by hand
# (x - mean) / std
z_dist = [(x - np.mean(normal_dist)) / np.std(normal_dist)
          for x in normal_dist]

np.mean(z_dist)
# Out:
# 3.383959779057477e-16

# %%
# Visualize it
fig, (ax0, ax1) = plt.subplots(nrows=2, sharex= True, figsize=(10, 6))

sns.histplot(data=normal_dist, ax=ax0)
ax0.set_title('Before Standardization')

sns.histplot(data=z_dist, ax=ax1)
ax1.set_title('After Standardization')

plt.tight_layout()
# Out:
# /Users/rebekahmclaughlin/anaconda3/envs/learn-env/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/rebekahmclaughlin/anaconda3/envs/learn-env/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# Talking about the standard normal distribution can be very convenient since the values correspond to the number of standard deviations above or below the mean.

# %% [markdown]
# ### $z$-Score

# %% [markdown]
# A **$z$-score** for a data point $x$ (in a normal distribution) is simply the distance to the mean in units of standard deviations
#
# $$\large z = \frac{x - \mu}{\sigma}$$
#
# By calculating the z-score of an individual point, we can see how unlikely a value is.

# %% [markdown]
# Here's a little site with some [interactive Gaussians](https://www.intmath.com/counting-probability/normal-distribution-graph-interactive.php)

# %% [markdown]
# #### 🧠 Knowledge Check

# %% [markdown]
# What would the $z$-score be for the middle of a normal curve?

# %% [markdown]
# ### The Empirical Rule

# %% [markdown]
# > Rule states that $68\%$ of the values of a normal distribution of data lie within 1 standard deviation ($\sigma$) of the mean, $95\%$ within $2\sigma$, and $99.7\%$ within $3\sigma$.
#
# This makes it really quick to look at a normal distribution and understand where values tend to lie

# %% [markdown]
# <img src='https://github.com/learn-co-students/dsc-0-09-12-gaussian-distributions-online-ds-ft-031119/blob/master/normalsd.jpg?raw=true' width=1000/>

# %% [markdown]
# #### 🧠 Knowledge Check

# %% [markdown]
# About what percentage of the values would be between a $z$-score of $-1$ and a $z$-score of $2$?
#
# <details>
#     <summary>Answer</summary>
#     About $82\%$
# </details>

# %% [markdown]
# # Exercises

# %% [markdown]
# ## Height $z$-score

# %% [markdown]
# The distribution of people's heights in the United States has a mean of 66 inches and a standard deviation of 4 inches. **Calculate the z-score of a height of 76 inches.**

# %% [markdown]
# <details>
#     <summary>Answer</summary>
#
# ```python
# # z-score: z = (x - mu) / std
# (76 - 66) / 4
# ```
# </details>

# %% [markdown]
# ## Height Empirical Rule

# %% [markdown]
# Use the empirical rule and the information above to determine about how many people are between **62 inches and 74 inches**.

# %%
heights = stats.norm(loc=66, scale=4)
round(heights.cdf(74) - heights.cdf(62),2) * 100
# Out:
# 82.0

# %% [markdown]
# <details>
#     <summary>Answer 1</summary>
#
# ```python
# # z-scores for 62" and 74":
# z_62 = (62 - 66) / 4
# z_74 = (74 - 66) / 4
# print(f'z_62:{z_62} \nz_74: {z_74}')
#
# percent = round(stats.norm.cdf(z_74) - stats.norm.cdf(z_62), 2) * 100
# print(f'Percentage of people between 62 and 74: {percent}')
# ```
# </details>

# %% [markdown]
# <details>
#     <summary>Answer 2</summary>
#
# ```python
# heights = stats.norm(loc=66, scale=4)
# round(heights.cdf(74) - heights.cdf(62),2) * 100
# ```
# </details>

# %% [markdown]
# ## Height Percentile

# %% [markdown]
# Assuming the above distribution of people's heights in the United States is approximately normal, what percent of people have a height less than **75 inches**?

# %%
heights.cdf(75)
# Out:
# 0.9877755273449553

# %% [markdown]
# <details>
#     <summary>Answer</summary>
#
# ```python
# heights.cdf(75)
# ```
# </details>

# %% [markdown]
# ## Bonus

# %% [markdown]
# Assuming the above distribution of people's heights in the United States is approximately normal, what range of heights contain the **middle 50% of values**,also known as the _interquartile range_ (IQR)?

# %%
heights.ppf(0.25), heights.ppf(0.75)
# Out:
# (63.30204099921567, 68.69795900078432)

# %% [markdown]
# <details>
#     <summary>Answer</summary>
#
# ```python
# heights.ppf(0.25), heights.ppf(0.75)
# ```
# </details>

# %% [markdown]
# ## Time for Pandas!
#
# Let's use the same Seattle City Employee data from the first Distributions lecture to check out what scaling looks like in practice!
#
# Data source: https://data.seattle.gov/City-Business/City-of-Seattle-Wage-Data/2khk-5ukd

# %%
# Read in the data
df = pd.read_csv('data/City_of_Seattle_Wage_Data_031422.csv')

# %%
# Check it
df.head()
# Out:
#                     Department    Last Name First Name             Job Title  \
# 0     Seattle Public Utilities    Batchelor      Craig  Civil Engrng Spec,Sr
# 1     Finance & Admin Services       Altice    Jeffrey         Auto Mechanic
# 2     Finance & Admin Services       Montes    Valeria          Cust Svc Rep
# 3              Fire Department       Kuklok    Rebecca        Cust Svc Rep *
# 4  Planning & Comm Development  Quirindongo       Rico            Executive3
#
#    Hourly Rate
# 0        53.740
# 1        39.780
# 2        29.450
# 3        29.450
# 4        97.164

# %%
# Rename the columns
df = df.rename(columns = lambda x: x.replace(" ", ""))

# %%
# Describe the numeric column
df.describe()
# Out:
#          HourlyRate
# count  11739.000000
# mean      47.817331
# std       16.722128
# min        5.530000
# 25%       35.400000
# 50%       47.340000
# 75%       59.550000
# max      187.767000

# %%
# Plot the hourly rate column
sns.kdeplot(df['HourlyRate']);
# Out:
# /Users/rebekahmclaughlin/anaconda3/envs/learn-env/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# How can we describe this distribution?
#
# <details>
#     <summary>Answer</summary>
#
# - Tri-modal?
#
# - Lots of outliers
#
# - Not perfectly normal, but not terrible
# </details>

# %% [markdown]
# ### Using Z-Scores

# %%
# Grab a sample row
sample_row = df.sample(1)
sample_row
# Out:
#                    Department LastName FirstName                  JobTitle  \
# 11096  Information Technology   Folker    Jordan  StratAdvsr2,Info Technol
#
#        HourlyRate
# 11096      62.072

# %%
#Calculate the z-score for that row's HourlyRate
(sample_row['HourlyRate'].values[0] - df['HourlyRate'].mean()) / df['HourlyRate'].std()
# Out:
# 0.8524434722713713

# %%
# Standardize the column
mu = df['HourlyRate'].mean()
sigma = df['HourlyRate'].std()
standardized_rate = [(x-mu)/sigma for x in df['HourlyRate']]

# %%
# Visualize it
fig, (ax1, ax2) = plt.subplots(nrows=2, ncols=1, sharex=False)
# Can toggle sharex to see the impact of the scale

sns.kdeplot(df['HourlyRate'], ax=ax1, label='Without Scaling')
ax1.legend()

sns.kdeplot(standardized_rate, ax=ax2, label='With Scaling')
ax2.legend()

plt.show()
# Out:
# /Users/rebekahmclaughlin/anaconda3/envs/learn-env/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/rebekahmclaughlin/anaconda3/envs/learn-env/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ## Central Limit Theorem (CLT)
#
# We mentioned that the distribution above doesn't seem very normal. But here's something cool:
#
# > "The central limit theorem states that the sampling distribution of the mean of any independent, random variable will be normal or nearly normal, if the sample size is large enough."
# - From [Stat Trek](https://stattrek.com/statistics/dictionary.aspx?definition=central_limit_theorem)

# %% [markdown]
# Let's look at an example, using the popular Iris dataset:
#
# <img src="images/probability-basics.gif" width=800>
#
# Here, taking samples of 15 flowers at a time and measuring their sepal lengths, we see that the the mean of the samples is normally distributed, where the mean of that normal distribution approximates the population mean.
#
# The coolest part is - this is true and works almost no matter what the original distribution is! (I say 'almost' because there are exceptions, of course). Even when we have _distinctly non-normal distributions_, we can use sampling to get a representation of population parameters (like the population mean).

# %% [markdown]
# ## Revisiting Sampling
#
# Before we apply a theorem that's related to sampling, we should remember some key things about sampling.
#
# <img src="images/sample_pop.png" alt="sampling example with circled people" width=800>
#
# Our goal when sampling is to find a representative group, from which we can infer population parameters.
#
# Remember: samples have statistics, populations have parameters.
#
# In order to do this effectively, our sample should be randomly selected and representative of our population (which sounds nice and easy, it's hard to do in practice). We are trying to minimize bias in our sample, but also we are sampling because we're trying to minimize cost as well.

# %% [markdown]
# ### Back to our Seattle Data
#
# Let's take 100 samples of 50 employees each time, and see what their average hourly rate is:

# %%
k = 100 # number of samples
n = 50 # number of employees per sample

# The full for loop version:
sample_means = []
for x in range(k):
    sample_emps = df.sample(n=n)
    sample_mean = sample_emps['HourlyRate'].mean()
    sample_means.append(sample_mean)

# %% [markdown]
# ### Create a list comprehension

# %%
sample_means = [df['HourlyRate'].sample(n).mean for x in range(k)]
sample_means
# Out:
# [<bound method Series.mean of 11673    30.0900
#  7467     94.1535
#  11338    31.3500
#  6508     38.5700
#  8449     43.9800
#  2772     45.8100
#  11382    45.6800
#  4478     41.4500
#  4744     53.7800
#  4682     55.4400
#  3514     61.8600
#  1176     56.3300
#  3302     75.7500
#  5467     31.1303
#  7172     34.1500
#  1496     38.9800
#  982      38.8300
#  11303    51.2200
#  7180     43.3400
#  2153     61.5960
#  1869     57.5500
#  7748     40.8600
#  8077     56.3900
#  5064     55.4400
#  4616     36.0500
#  2265     39.5900
#  10950    35.1600
#  11358    19.5100
#  5133     70.6300
#  364      38.8100
#  3844     55.4400
#  8791     32.8400
#  9540     25.5800
#  4289     37.9800
#  7408     46.6800
#  8774     32.2300
#  4053     66.3500
#  4410     43.3400
#  1560     75.7500
#  4950     31.3500
#  8487     34.4700
#  3487     36.0500
#  5297     30.0900
#  3026     19.5100
#  9217     67.4900
#  9603     64.2100
#  9943     59.3800
#  4407     60.4100
#  6606     62.2360
#  11491    40.8600
#  Name: HourlyRate, dtype: float64>,
#  <bound method Series.mean of 10785    54.680
#  4880     38.430
#  9289     19.090
#  11450    44.790
#  4708     70.949
#  455      67.877
#  2715     57.380
#  1186     34.350
#  4203     25.580
#  11603    29.030
#  343      55.672
#  3727     31.350
#  10113    53.200
#  996      57.980
#  10884    77.050
#  1170     51.600
#  3924     34.050
#  10660    71.725
#  6959     39.280
#  458      61.758
#  7222     48.310
#  8784     50.170
#  7839     39.280
#  5017     42.570
#  6440     40.840
#  5375     34.200
#  6695     54.400
#  2477     18.560
#  6529     68.540
#  2907     32.230
#  11258    71.820
#  5090     34.050
#  7203     53.020
#  9478     30.090
#  1720     31.350
#  3193     61.860
#  8366     36.050
#  8268     51.320
#  5753     63.142
#  7586     46.680
#  174      36.050
#  6916     39.590
#  3279     38.950
#  6837     48.480
#  2494     43.150
#  2834     39.280
#  8789     43.150
#  11158    54.190
#  934      39.590
#  1187     37.840
#  Name: HourlyRate, dtype: float64>,
#  <bound method Series.mean of 3964     67.9900
#  11699    18.5600
#  6987     46.0600
#  8195     64.2120
#  7994     63.0600
#  6401     34.0500
#  8806     19.2900
#  10603    43.4200
#  10656    69.1100
#  4582     45.9600
#  11193    18.5600
#  6740     25.5500
#  8734     32.6000
#  10803    22.8600
#  7154     49.1040
#  9340     40.0600
#  3984     39.2200
#  9419     36.0500
#  7569     77.8800
#  1901     53.8070
#  6907     49.2400
#  3275     50.8600
#  10662    49.4900
#  11533    25.5800
#  7822     69.1100
#  2550     35.4600
#  10556    57.5500
#  2164     37.8400
#  3614     50.4300
#  1511     53.4500
#  1473     19.5100
#  5419     58.2310
#  8545     20.2800
#  11528    39.2800
#  10057    70.6300
#  7348     41.4500
#  6900     61.6850
#  8604     54.2900
#  3862     46.9349
#  8726     66.6410
#  8522     19.5100
#  4996     56.3900
#  513      43.3400
#  9522     18.5600
#  5634     18.5600
#  10761    72.7740
#  10530    17.2700
#  4526     41.8300
#  7519     19.5100
#  10462    30.0900
#  Name: HourlyRate, dtype: float64>,
#  <bound method Series.mean of 4003     40.0800
#  715      43.2700
#  5525     33.1400
#  5920     47.3400
#  11189    38.5700
#  2135     31.3500
#  2168     44.9500
#  5344     61.8600
#  4394     58.7480
#  4921     32.8500
#  5878     67.8980
#  8519     19.5100
#  7570     40.7200
#  10176    36.5700
#  643      24.9200
#  7972     65.3632
#  8452     46.0600
#  56       60.3200
#  1938     69.6000
#  1580     36.0500
#  11145    55.4400
#  692      68.5570
#  4095     46.6800
#  300      60.5800
#  1941     61.8600
#  9215     61.6600
#  9876     18.5600
#  9532     21.9600
#  7151     49.4900
#  7603     62.9400
#  3298     50.8600
#  4015     61.0000
#  4292     37.8400
#  9115     57.5100
#  114      34.4700
#  3187     93.3400
#  2430     46.4800
#  1369     19.2900
#  201      39.2800
#  3292     57.8700
#  8319     31.3500
#  4759     38.4000
#  11077    53.2000
#  7916     49.4900
#  6352     41.6100
#  4889     56.2500
#  892      55.3900
#  10583    40.6700
#  4085     31.3500
#  10509    32.6700
#  Name: HourlyRate, dtype: float64>,
#  <bound method Series.mean of 11697    38.9800
#  10755    61.8600
#  383      39.5900
#  1826     60.7800
#  10321    56.4600
#  3664     65.8200
#  4929     40.0800
#  8403     67.4900
#  9944     49.7500
#  4641     75.3900
#  5617     31.3500
#  10291    50.8600
#  11359    19.0900
#  10492    37.1000
#  6314     33.1400
#  6106     53.8800
#  11077    53.2000
#  4751     74.9567
#  767      46.6800
#  775      55.4400
#  11513    55.3400
#  11247    76.4300
#  5508     19.0900
#  5542     51.3900
#  5055     61.5740
#  10820    66.4040
#  8677     36.4700
#  1512     19.5100
#  2895     45.9600
#  3510     66.0900
#  9289     19.0900
#  5710     63.5920
#  5774     45.9600
#  3854     19.5100
#  3887     49.2400
#  9346     73.0730
#  5411     54.2900
#  5771     45.9600
#  1623     55.4400
#  2009     31.3600
#  10377    40.8400
#  5779     44.5800
#  9786     52.4100
#  1265     51.6490
#  2865     40.0800
#  6647     53.2000
#  9329     32.8500
#  6046     57.5500
#  582      71.6710
#  8161     46.4800
#  Name: HourlyRate, dtype: float64>,
#  <bound method Series.mean of 8009     57.3800
#  935      44.1400
#  4406     33.4400
#  305      33.3300
#  4844     18.5600
#  300      60.5800
#  1534     33.7800
#  9629     33.6400
#  4410     43.3400
#  5878     67.8980
#  5998     54.3450
#  8956     19.5100
#  937      35.8000
#  6885     18.5600
#  10836    45.7500
#  921      56.6120
#  6123     31.3500
#  10124    54.2900
#  652      37.3200
#  2111     49.0400
#  1689     37.3200
#  8252     55.4400
#  10675    46.6800
#  366      43.2700
#  1264     65.9240
#  2820     53.4500
#  5025     61.1920
#  1979     36.0500
#  10305    59.5300
#  2372     67.4900
#  2536     61.1100
#  10262    34.0800
#  1877     55.4400
#  3982     34.0800
#  5656     42.9600
#  8354     54.4000
#  2434     29.0300
#  10535    40.2200
#  4948     69.6000
#  4685     74.7900
#  11491    40.8600
#  8384     57.7980
#  8666     42.9600
#  138      30.0900
#  6867     43.4900
#  8131     58.9759
#  1792     61.0010
#  1803     41.1700
#  878      36.3300
#  3619     57.4400
#  Name: HourlyRate, dtype: float64>,
#  <bound method Series.mean of 3844     55.440
#  2767     61.001
#  3169     63.630
#  6960     18.560
#  51       70.610
#  5266     18.560
#  4178     20.750
#  5375     34.200
#  9384     51.320
#  6258     49.450
#  9754     34.050
#  590      57.870
#  5806     44.010
#  6339     50.860
#  2127     69.563
#  2444     36.050
#  8760     53.000
#  11281    28.310
#  6827     31.350
#  9443     44.950
#  2987     37.100
#  4504     24.110
#  4271     53.450
#  2210     57.440
#  3597     46.680
#  5127     45.750
#  5292     38.430
#  6803     54.290
#  9864     56.650
#  6547     49.340
#  5912     55.990
#  2084     36.050
#  7054     50.430
#  1304     64.581
#  426      67.490
#  957      31.020
#  5444     31.350
#  11387    34.810
#  2398     52.410
#  5072     34.050
#  577      45.960
#  1176     56.330
#  11092    53.200
#  166      74.111
#  5796     23.620
#  1569     41.830
#  5789     82.008
#  5958     49.890
#  668      43.270
#  4163     19.510
#  Name: HourlyRate, dtype: float64>,
#  <bound method Series.mean of 4842     69.110
#  6472     58.220
#  6853     32.850
#  6475     35.260
#  3236     68.000
#  4538     30.090
#  3513     57.440
#  4139     43.150
#  1691     32.230
#  706      67.490
#  9969     18.560
#  3572     41.380
#  777      34.470
#  7771     58.750
#  11133    36.900
#  9772     72.750
#  4995     56.870
#  3988     33.330
#  7843     52.320
#  2707     69.563
#  10396    50.430
#  6576     51.320
#  2447     36.050
#  11513    55.340
#  1555     42.570
#  7660     54.200
#  10198    41.170
#  3001     29.730
#  3653     71.425
#  7154     49.104
#  83       24.610
#  4303     19.510
#  8514     53.500
#  2189     58.220
#  3841     74.914
#  6731     74.186
#  9565     56.586
#  3975     42.440
#  1605     70.630
#  2756     54.340
#  7626     59.800
#  5021     55.340
#  4681     55.302
#  9062     77.050
#  8506     41.380
#  4673     55.030
#  5223     30.090
#  11583    27.190
#  9107     27.600
#  5406     47.310
#  Name: HourlyRate, dtype: float64>,
#  <bound method Series.mean of 1774     57.870
#  4923     66.024
#  1127     66.050
#  3991     39.280
#  1501     32.050
#  935      44.140
#  9254     51.700
#  3356     72.506
#  3054     52.230
#  1348     23.400
#  6031     62.350
#  6174     36.130
#  11461    35.160
#  3436     74.463
#  5941     33.780
#  3103     58.534
#  739      41.660
#  4074     55.440
#  2731     28.310
#  6655     39.700
#  6001     38.860
#  3814     29.030
#  1742     67.321
#  2875     47.849
#  8210     53.020
#  1920     67.490
#  10834    55.440
#  5049     58.360
#  470      40.860
#  1591     69.040
#  1512     19.510
#  8815     44.090
#  9743     52.180
#  4338     82.191
#  9725     65.899
#  2422     61.860
#  6750     31.350
#  3361     68.800
#  2355     27.190
#  3250     57.870
#  11000    48.753
#  11383    33.440
#  3268     57.870
#  6367     39.270
#  6488     35.740
#  2443     45.680
#  3654     69.600
#  3610     57.550
#  204      70.920
#  1761     67.255
#  Name: HourlyRate, dtype: float64>,
#  <bound method Series.mean of 6382     39.5900
#  6521     47.3400
#  6419     57.7000
#  8848     31.3500
#  8199     37.5400
#  5440     55.6300
#  4191     41.3800
#  4253     61.8600
#  5450     52.1800
#  6758     36.0500
#  5048     54.4000
#  7247     19.5100
#  7672     60.2550
#  1490     40.0600
#  6301     61.6300
#  4828     49.0400
#  2865     40.0800
#  1689     37.3200
#  3057     18.5600
#  584      41.6600
#  10609    19.5100
#  11132    36.9000
#  3618     78.1440
#  618      18.5600
#  6980     51.3400
#  8347     54.2900
#  7356     66.6170
#  4545     19.0900
#  8708     41.0700
#  10058    49.4900
#  10952    49.4000
#  8414     57.4713
#  3681     37.1500
#  3012     19.5100
#  4063     23.1400
#  475      49.8200
#  5896     31.3500
#  2686     35.4600
#  5486     51.0700
#  6609     57.3800
#  2888     25.4600
#  9407     17.2700
#  8895     30.0900
#  703      41.8500
#  6057     57.9600
#  8393     50.3800
#  8511     18.5600
#  7143     43.1500
#  8928     60.1600
#  7527     27.4600
#  Name: HourlyRate, dtype: float64>,
#  <bound method Series.mean of 8650     39.0500
#  10541    44.0100
#  11519    43.3400
#  6226     60.5800
#  10370    73.7970
#  3291     77.8370
#  11493    22.8600
#  6706     27.1900
#  10420    69.6000
#  4558     43.3400
#  7403     42.9600
#  10585    31.3500
#  5426     57.9850
#  5825     43.3400
#  3982     34.0800
#  447      61.9100
#  637      60.9050
#  656      38.3100
#  2870     63.4368
#  11166    33.3600
#  216      80.0700
#  6418     48.2500
#  6362     18.5600
#  7633     35.4600
#  2243     18.5600
#  2253     39.6700
#  6378     79.3200
#  9225     31.3500
#  9017     61.0000
#  9875     61.8600
#  7501     61.8600
#  5662     78.5310
#  7238     40.8600
#  5581     51.3200
#  3198     31.3500
#  8728     36.9000
#  5888     44.0900
#  3515     57.8700
#  7036     46.6800
#  4050     35.7900
#  4690     43.3400
#  6168     46.9000
#  7399     36.0500
#  2635     42.0600
#  628      23.6400
#  3357     53.7800
#  5985     58.6800
#  3860     55.6800
#  9112     50.8600
#  824      47.7400
#  Name: HourlyRate, dtype: float64>,
#  <bound method Series.mean of 10353    63.005
#  9231     63.990
#  6005     27.600
#  9100     74.950
#  6262     38.860
#  269      59.800
#  132      68.319
#  314      59.530
#  8552     47.950
#  691      75.985
#  3290     56.650
#  4097     48.485
#  7        28.310
#  3746     46.900
#  8834     41.070
#  9950     41.380
#  5366     46.680
#  3513     57.440
#  1735     37.290
#  4259     47.340
#  553      38.600
#  8915     51.390
#  11714    17.270
#  5524     30.090
#  3527     57.870
#  10491    29.880
#  6718     21.960
#  2727      5.530
#  374      40.720
#  9857     18.560
#  9575     44.950
#  3279     38.950
#  7910     45.960
#  6080     57.330
#  8476     55.390
#  2303     54.290
#  8242     46.680
#  8151     54.290
#  11035    37.340
#  745      38.950
#  10000    37.980
#  1422     19.090
#  8712     35.050
#  10086    69.600
#  5573     34.150
#  4209     61.190
#  8789     43.150
#  8533     18.560
#  7509     64.160
#  1911     47.960
#  Name: HourlyRate, dtype: float64>,
#  <bound method Series.mean of 10969    39.590
#  7404     42.960
#  4006     59.353
#  11715    52.020
#  987      19.510
#  333      54.210
#  8692     39.160
#  7402     67.656
#  11735    33.440
#  10275    57.740
#  6817     18.560
#  2718     38.980
#  6046     57.550
#  10756    36.050
#  3137     21.960
#  1920     67.490
#  6780     47.690
#  5601     52.410
#  4620     51.320
#  10956    35.050
#  2822     67.423
#  7897     54.190
#  3686     48.990
#  9615     77.050
#  7411     30.730
#  6053     37.840
#  9844     25.550
#  8909     36.050
#  9348     69.600
#  2146     59.695
#  7325     62.859
#  5300     31.350
#  8164     38.950
#  2867     41.380
#  10098    55.440
#  9946     35.460
#  11282    60.160
#  7109     30.090
#  3694     54.600
#  1215     63.515
#  10797    43.340
#  622      18.560
#  9505     71.840
#  8807     38.570
#  3241     36.050
#  3362     36.050
#  9524     41.380
#  7233     53.200
#  11022    44.790
#  8495     46.680
#  Name: HourlyRate, dtype: float64>,
#  <bound method Series.mean of 3160     73.7000
#  5276     23.1400
#  11668    34.8100
#  3934     31.3500
#  3765     29.0300
#  8478     46.2900
#  6280     61.3910
#  8235     54.6000
#  4784     56.6500
#  186      38.8100
#  3729     41.6600
#  8383     55.3400
#  7150     31.7000
#  197      51.7000
#  8688     44.0100
#  2225     38.6400
#  7839     39.2800
#  10611    63.5760
#  7985     34.0800
#  815      41.3800
#  10269    54.3400
#  5436     66.6240
#  7247     19.5100
#  11148    36.9000
#  3022     61.8900
#  4884     65.1700
#  7245     28.0000
#  2166     48.4800
#  2843     29.0300
#  9308     86.3080
#  9065     64.7640
#  4497     56.8200
#  3458     65.8160
#  3864     53.5000
#  6890     63.4548
#  10386    53.4500
#  4373     26.0500
#  5103     55.4400
#  6917     41.6300
#  1650     33.7800
#  2669     53.5000
#  3432     36.0500
#  4241     30.0900
#  8537     19.6600
#  5582     50.0300
#  11325    46.5100
#  5463     65.9800
#  5526     43.1500
#  3286     85.5060
#  8030     51.0700
#  Name: HourlyRate, dtype: float64>,
#  <bound method Series.mean of 10194    58.7500
#  8587     31.3500
#  8027     55.4400
#  10490    47.5100
#  1974     60.0600
#  7112     18.5600
#  8849     51.5235
#  6840     54.2900
#  3356     72.5060
#  10170    42.5700
#  6006     60.8940
#  1534     33.7800
#  293      62.2380
#  504      37.2900
#  5267     50.3800
#  6496     54.4000
#  9639     53.5000
#  7828     57.5500
#  7922     38.3100
#  7499     43.7700
#  9566     32.8500
#  10381    57.7400
#  2081     46.6800
#  1379     46.6800
#  8704     28.0000
#  2930     60.5800
#  8387     36.3100
#  5651     23.4000
#  3599     51.2640
#  7147     46.6800
#  2944     48.7800
#  11224    46.3700
#  10167    46.6800
#  6853     32.8500
#  2893     25.5800
#  8754     44.9500
#  1333     19.0900
#  7475     36.0500
#  9526     70.9220
#  4262     40.6600
#  4985     43.7700
#  10212    39.2800
#  6086     33.3300
#  6675     65.0720
#  9987     53.7290
#  7514     62.4200
#  4861     39.2800
#  2971     66.3500
#  9569     47.4070
#  9001     51.2500
#  Name: HourlyRate, dtype: float64>,
#  <bound method Series.mean of 10149    66.617
#  326      64.570
#  1349     25.390
#  9228     57.870
#  5788     46.921
#  5718     19.510
#  11045    19.510
#  2010     72.750
#  9585     52.200
#  3572     41.380
#  3440     41.660
#  1526     19.090
#  10172    41.660
#  8527     54.290
#  1353     19.510
#  10072    30.090
#  11669    21.960
#  6930     20.750
#  5242     30.090
#  6664     55.340
#  3986     50.030
#  8498     61.860
#  10551    41.660
#  3948     30.090
#  119      33.780
#  242      43.770
#  9880     31.700
#  5226     55.340
#  3880     47.480
#  3258     60.060
#  11084    31.350
#  7998     48.480
#  9454     56.820
#  5217     39.590
#  2783     30.090
#  7946     33.360
#  7965     36.050
#  4762     70.920
#  10178    66.140
#  8606     38.950
#  5795     46.680
#  8763     43.120
#  9770     57.870
#  5568     40.120
#  11230    45.750
#  492      55.440
#  8003     62.350
#  9648     53.500
#  8652     37.100
#  1900     25.580
#  Name: HourlyRate, dtype: float64>,
#  <bound method Series.mean of 7944     69.563
#  7049     47.690
#  1945     60.580
#  8985     44.320
#  2149     41.170
#  8920     47.690
#  6946     34.050
#  1956      5.530
#  10441    33.780
#  8544     36.050
#  11322    38.314
#  7534     70.000
#  545      62.890
#  10632    28.000
#  10515    38.640
#  8041     54.400
#  5842     55.390
#  11223    20.750
#  2322     43.980
#  10769    61.860
#  8969     18.560
#  9552     37.100
#  10538    18.560
#  4736     77.880
#  2515     82.007
#  4743     62.510
#  3504     54.400
#  10058    49.490
#  6099     54.600
#  4348     33.440
#  5848     33.440
#  1617     64.715
#  5147     74.221
#  7893     35.400
#  1830     85.305
#  1660     51.700
#  4916     38.070
#  6410     69.600
#  1897     39.280
#  9563     38.570
#  4369     19.290
#  3106     28.000
#  3887     49.240
#  1869     57.550
#  10780    35.050
#  3096     48.480
#  2372     67.490
#  5792     47.340
#  11549    46.680
#  2601     53.087
#  Name: HourlyRate, dtype: float64>,
#  <bound method Series.mean of 10319     35.050
#  3064      59.467
#  9642      55.630
#  9508      34.810
#  2755      46.680
#  1772      38.570
#  3501     105.072
#  11555     36.050
#  5325      43.490
#  3126      65.170
#  6404      56.089
#  4491      56.721
#  3353      57.870
#  3199      94.178
#  10663     57.440
#  6063      44.140
#  9656      31.630
#  2645      31.700
#  11469    100.893
#  7804      27.190
#  10584     60.230
#  2930      60.580
#  9316      20.750
#  5470      68.557
#  10191     55.600
#  134       46.050
#  371      141.273
#  7873      25.460
#  4089      35.790
#  6102      60.840
#  9182      44.860
#  3254      58.750
#  5445     187.767
#  10976     39.280
#  10243     61.915
#  5794      61.020
#  4197      58.360
#  188       53.360
#  4443      61.630
#  111       19.290
#  5197      31.020
#  5663      28.900
#  7685      60.890
#  8518      46.060
#  4083      54.290
#  7240      36.050
#  5476      77.050
#  1108      64.635
#  4007      57.870
#  7267      39.730
#  Name: HourlyRate, dtype: float64>,
#  <bound method Series.mean of 7418     27.4600
#  2755     46.6800
#  6362     18.5600
#  3306     58.7500
#  4812     31.3500
#  11493    22.8600
#  11259    51.7000
#  9862     41.6300
#  1626     50.8600
#  6922     37.1000
#  7968     66.4403
#  1014     55.4400
#  1133     61.8600
#  10651    34.0500
#  686      46.6800
#  6214     42.9200
#  3455     57.8700
#  10944    48.2500
#  11446    43.9800
#  9037     63.5450
#  3079     30.0900
#  2495     46.0700
#  5433     57.8700
#  2796     24.9200
#  2716     41.0600
#  646      49.4900
#  7263     64.3100
#  5033     47.3200
#  4740     74.4650
#  9095     56.4600
#  6178     18.5600
#  9072     63.3200
#  1306     58.7000
#  5798     18.5600
#  5726     24.1100
#  763      44.7900
#  4123     37.8400
#  10166    54.6000
#  10579    31.3500
#  1633     31.3500
#  11169    26.6000
#  7314     19.0900
#  4033     33.7900
#  9249     69.5630
#  3162     54.2900
#  2678     34.4700
#  8927     47.6200
#  7866     51.3800
#  8269     46.6800
#  6631     30.0900
#  Name: HourlyRate, dtype: float64>,
#  <bound method Series.mean of 6187     50.8600
#  4279     41.0300
#  9858     60.0966
#  5807     64.5990
#  8571     59.8240
#  9001     51.2500
#  8486     44.9500
#  9018     50.8600
#  6222     35.7400
#  1771     37.3200
#  10082    54.3400
#  9452     33.2100
#  4581     41.4800
#  7643     18.5600
#  4295     70.6860
#  889      53.0200
#  6744     18.5600
#  3456     37.1000
#  2408     57.3800
#  2254     47.3400
#  4200     74.2660
#  697      18.5600
#  8227     18.5600
#  9993     51.3200
#  6063     44.1400
#  7593     37.2900
#  7662     59.8000
#  340      36.0500
#  6210     37.2900
#  6597     74.5000
#  2754     70.9150
#  8890     49.4000
#  6061     99.4000
#  3980     39.2800
#  7618     61.8600
#  6432     36.5500
#  5506     59.5500
#  10416    30.0900
#  3822     18.5600
#  5904     38.2900
#  7868     41.2600
#  4102     25.5800
#  2893     25.5800
#  7169     35.7900
#  2988     46.6800
#  2304     61.2010
#  9953     57.7000
#  10136    41.6800
#  9731     18.5600
#  687      55.3400
#  Name: HourlyRate, dtype: float64>,
#  <bound method Series.mean of 11240    66.6170
#  4504     24.1100
#  1499     44.0100
#  7483     74.0000
#  5295     67.3750
#  521      57.4400
#  9263     36.0500
#  3724     51.3200
#  2649     42.3800
#  9131     39.7000
#  8844     34.4700
#  5762     30.0900
#  5879     56.8200
#  7121     91.1694
#  8100     34.4700
#  4083     54.2900
#  3934     31.3500
#  7632     49.6100
#  6344     33.3300
#  4127     45.9600
#  5663     28.9000
#  8258     77.0500
#  5421     59.7390
#  10888    38.5700
#  5054     55.4400
#  8745     39.2800
#  5225     54.4000
#  5934     65.0910
#  6308     40.0300
#  2092     55.3400
#  3795     46.6800
#  5346     24.6100
#  3539     77.8460
#  8792     49.4400
#  5681     18.5600
#  6874     46.6800
#  7480     61.0200
#  9759     63.3200
#  8203     35.9500
#  9219     37.1000
#  2382     40.8300
#  106      31.3500
#  3099     64.5100
#  9210     36.0500
#  10289    69.0110
#  3781     59.5600
#  4091     64.5730
#  7018     51.3200
#  3012     19.5100
#  10681    46.6800
#  Name: HourlyRate, dtype: float64>,
#  <bound method Series.mean of 985       53.5100
#  673       70.2670
#  446       70.0100
#  10079     39.2800
#  50        47.1600
#  9301      31.3500
#  6110      41.8300
#  9334      31.3500
#  293       62.2380
#  402      151.8084
#  715       43.2700
#  7999      63.3200
#  11386     34.8100
#  3490      41.4500
#  6682      72.7500
#  5554      32.4800
#  8619      53.2300
#  9914      68.6660
#  11299     24.7800
#  2100      53.7400
#  7182      36.3300
#  8799      45.9600
#  2948      59.8000
#  2204      32.8500
#  11214     34.0500
#  9544      55.6500
#  10206     37.9800
#  8269      46.6800
#  2907      32.2300
#  2827      50.4300
#  4234      19.2900
#  1994      54.3400
#  6621      49.4900
#  1862      61.3600
#  6013      63.4200
#  11157     52.5300
#  2410      46.0600
#  9370      31.3500
#  6789      43.9800
#  8506      41.3800
#  1414      64.2120
#  5055      61.5740
#  3456      37.1000
#  3679      26.0500
#  10389     29.5400
#  7222      48.3100
#  2951      21.9600
#  550       33.3300
#  7393      18.5600
#  4658      46.6800
#  Name: HourlyRate, dtype: float64>,
#  <bound method Series.mean of 9619     62.6880
#  8755     18.5600
#  7153     51.7350
#  6556     49.8200
#  10905    39.2800
#  6472     58.2200
#  3816     66.9590
#  7995     51.0700
#  10929    46.0600
#  4447     34.8100
#  4340     31.0200
#  9833     37.2900
#  9033     46.6800
#  6948     27.4600
#  8360     53.5100
#  9423     19.5100
#  10694    43.3400
#  2309     46.4600
#  4343     61.8600
#  6415     38.8300
#  1106     32.4800
#  2013     60.5800
#  9295     45.2030
#  2852     45.9600
#  1626     50.8600
#  0        53.7400
#  8654     49.4038
#  1214     36.8774
#  2980     68.7900
#  9597     46.9000
#  2475     41.1700
#  9679     35.0500
#  4332     33.7800
#  11311    60.8400
#  8982     29.0300
#  9851     37.2900
#  3153     40.3700
#  9305     57.8700
#  199      36.4700
#  9693     61.8600
#  10924    51.2200
#  11067    30.0900
#  3031     56.8200
#  11702    18.5600
#  930      18.5600
#  7976     38.0000
#  1686     42.1495
#  6109     60.5800
#  2962     65.7500
#  4475     61.8900
#  Name: HourlyRate, dtype: float64>,
#  <bound method Series.mean of 2657     19.5100
#  4170     45.9600
#  6451     51.0700
#  7826     36.4700
#  9599     35.7400
#  5066     41.6600
#  10496    30.0900
#  6818     74.6500
#  7028     64.1115
#  750      55.6000
#  8592     53.5000
#  9301     31.3500
#  3628     61.8600
#  9412     39.1600
#  6582     47.3400
#  4790     74.4630
#  5367     39.2800
#  8774     32.2300
#  7610     54.9530
#  10129    68.3012
#  10823    62.4300
#  10674    24.9200
#  2922     27.1900
#  16       28.0000
#  3007     51.7000
#  2486     53.4100
#  5032     44.8200
#  6904     79.0070
#  11368    18.5600
#  7213     40.6700
#  8093     25.5800
#  9891     63.5920
#  3881     40.0800
#  1868     30.0900
#  5365     65.9800
#  10296    85.6160
#  3850     56.8700
#  11435    36.3100
#  10012    31.3500
#  3206     30.0900
#  833      69.6000
#  7881     35.4600
#  541      57.8700
#  6463     63.9500
#  10888    38.5700
#  7209     71.8000
#  398      62.0030
#  9038     52.4100
#  3088     18.5600
#  10374    66.6910
#  Name: HourlyRate, dtype: float64>,
#  <bound method Series.mean of 4103      53.5000
#  7725      60.8400
#  6129      50.8600
#  2777      31.8800
#  7540     124.1840
#  6885      18.5600
#  8996      53.0410
#  1682      44.9500
#  10124     54.2900
#  2722      18.5600
#  4110      20.6700
#  6759      36.0500
#  6554      32.8500
#  4816      54.6200
#  1511      53.4500
#  1372      45.7500
#  1544      55.4400
#  1623      55.4400
#  4146      30.0900
#  8524      67.6140
#  3356      72.5060
#  10987     31.3500
#  8312      40.3100
#  5644      28.0000
#  8751      27.0900
#  6935      66.0680
#  9312      24.9200
#  10916     43.3400
#  11337     30.0900
#  10675     46.6800
#  7421      28.3100
#  2672      35.7900
#  4292      37.8400
#  1467      64.2120
#  10406     51.3200
#  6301      61.6300
#  1214      36.8774
#  6068      66.3500
#  719       39.7000
#  1086      51.7000
#  11270     19.5100
#  4555      40.0800
#  7795      69.6000
#  1862      61.3600
#  8844      34.4700
#  2049      58.3600
#  974       54.2900
#  6470      68.4752
#  7898      50.8600
#  1916      59.5300
#  Name: HourlyRate, dtype: float64>,
#  <bound method Series.mean of 10120    24.9200
#  2165     29.1100
#  372      80.0700
#  2185     59.5500
#  4404     40.0800
#  9134     41.6300
#  3244     61.7490
#  5017     42.5700
#  6103     52.9400
#  2827     50.4300
#  10003    69.5780
#  7635     75.7570
#  1429     28.0000
#  8435     70.7940
#  1187     37.8400
#  493      51.3200
#  2929     73.5230
#  8017     46.6800
#  9560     31.7000
#  8933     30.0900
#  11462    31.3500
#  3491     33.3600
#  1697     46.9349
#  10525    57.2330
#  5221     40.8300
#  6806     43.9800
#  75       78.1220
#  8462     41.0600
#  8941     45.0200
#  2931     28.3100
#  3393     57.7000
#  11130    36.9000
#  8786     53.5080
#  5936     19.5100
#  4021     39.2800
#  419      66.6170
#  10536    37.8400
#  1036     71.7900
#  8603     54.2900
#  1968     41.6100
#  10609    19.5100
#  170      69.6000
#  3343     80.9300
#  7676     31.3500
#  8650     39.0500
#  10366    76.4700
#  8112     61.4200
#  9419     36.0500
#  8160     41.1700
#  319      60.2300
#  Name: HourlyRate, dtype: float64>,
#  <bound method Series.mean of 8240     36.4700
#  5345     51.3900
#  7952     66.8790
#  5450     52.1800
#  9431     54.6100
#  8615     18.9100
#  8978     18.5600
#  5036     61.2802
#  9859     57.4400
#  7237     66.4480
#  2295     46.9000
#  7654     64.5100
#  3207     43.2700
#  5663     28.9000
#  4957     69.6000
#  3032     33.7800
#  9721     54.2900
#  4779     35.7900
#  10953    61.8600
#  7865     44.7200
#  6172     54.3400
#  10545    30.0900
#  5243     46.6800
#  4709     65.1700
#  530      46.6800
#  4981     34.4700
#  4138     19.5100
#  10979    33.7800
#  10488    52.4100
#  6078     34.0800
#  11094    19.5100
#  6740     25.5500
#  10821    25.5800
#  3607     46.6800
#  8255     54.2900
#  4973     58.7100
#  4283     18.5600
#  3947     30.0900
#  117      33.7800
#  2720     33.1600
#  1078     52.5600
#  9699     39.7000
#  5856     55.4400
#  3828     53.2400
#  3290     56.6500
#  1297     44.9500
#  2535     53.2000
#  8775     38.1200
#  4698     27.1900
#  3958     47.6900
#  Name: HourlyRate, dtype: float64>,
#  <bound method Series.mean of 1064     67.4230
#  10397    57.5390
#  9829     18.5600
#  3000     24.1100
#  695      57.8700
#  2307     46.6800
#  2338     54.9490
#  4049     44.9500
#  4755     40.8600
#  6835     49.4000
#  9338     18.5600
#  8905     37.3200
#  2462     47.3400
#  9295     45.2030
#  79       34.4700
#  11320    24.9200
#  2136     57.4400
#  10983    64.2418
#  1026     30.0900
#  6501     43.1600
#  11536    59.9560
#  4030     50.0300
#  2145     48.4800
#  3272     84.2200
#  2016     31.3500
#  2086     55.2300
#  2943     56.2500
#  4336     30.0900
#  10467    53.0400
#  550      33.3300
#  5728     49.3600
#  3425     46.6800
#  9388     36.4700
#  5818     55.6500
#  3342     38.3100
#  1154     55.4400
#  4608     57.8700
#  4112     44.0100
#  1826     60.7800
#  9081     42.5700
#  1721     61.8600
#  2245     37.2900
#  9917     59.4000
#  8449     43.9800
#  8523     18.5600
#  3558     56.3100
#  9551     36.0500
#  10227    77.1900
#  2650     18.5600
#  5167     31.3500
#  Name: HourlyRate, dtype: float64>,
#  <bound method Series.mean of 9498     63.4600
#  6765     57.4400
#  8087     25.4600
#  6699     34.0500
#  10419    22.2600
#  9641     37.2900
#  8461     56.3100
#  6806     43.9800
#  3163     63.6920
#  9198     43.1035
#  6837     48.4800
#  9672     70.8260
#  11258    71.8200
#  2684     62.7400
#  4907     66.3800
#  6706     27.1900
#  7994     63.0600
#  11058    30.0900
#  4195     18.5600
#  2958     59.8000
#  1902     71.3650
#  8398     52.4100
#  1748     61.8600
#  1356     30.0100
#  7245     28.0000
#  11033    38.9800
#  5564     54.2900
#  10105    49.6100
#  1792     61.0010
#  8933     30.0900
#  6        23.4000
#  6932     43.1500
#  7856     63.8900
#  3708     67.4900
#  7225     43.1500
#  2568     56.5000
#  7263     64.3100
#  8466     54.2900
#  2274     46.4800
#  5625     43.1500
#  647      67.4900
#  10125    66.6170
#  1166     56.3100
#  7550     62.4100
#  9738     53.4500
#  3835     41.8300
#  11433    59.3530
#  7208     45.9600
#  9089     58.2200
#  7155     56.3100
#  Name: HourlyRate, dtype: float64>,
#  <bound method Series.mean of 10559    43.1500
#  10760    57.8700
#  4895     69.6000
#  4414     35.4600
#  8334     21.9600
#  10515    38.6400
#  5868     33.6400
#  156      41.8300
#  4776     66.6170
#  10530    17.2700
#  7868     41.2600
#  548      61.8600
#  3124     62.6800
#  2103     38.9500
#  6629     31.7000
#  879      51.3900
#  9782     57.3880
#  9656     31.6300
#  909      67.6560
#  1588     72.7500
#  431      57.9500
#  3198     31.3500
#  216      80.0700
#  8883     56.3300
#  4515     41.6600
#  8410     63.3200
#  404      54.6000
#  4172     43.3400
#  4888     17.2700
#  2108     57.7000
#  2415     35.2600
#  6980     51.3400
#  4473     56.2500
#  4252     19.5100
#  11051    33.7800
#  6605     58.3600
#  8053     57.7000
#  9326     61.6300
#  1765     73.3373
#  5739     34.0800
#  3707     53.5080
#  2359     33.7800
#  8385     61.7570
#  8739     36.9000
#  11124    61.8500
#  10012    31.3500
#  5540     49.4000
#  5864     84.5600
#  1712     35.1300
#  5580     49.2400
#  Name: HourlyRate, dtype: float64>,
#  <bound method Series.mean of 9238     55.440
#  8190     55.440
#  4373     26.050
#  5499     34.050
#  7733     43.340
#  8343     72.750
#  10011    48.590
#  8180     34.080
#  8050     44.150
#  3415     34.050
#  9323     60.580
#  8173     52.490
#  5506     59.550
#  4148     51.320
#  5739     34.080
#  3713     55.340
#  6924     51.220
#  10995    26.050
#  3420     70.880
#  5777     36.470
#  10473    31.350
#  5580     49.240
#  8445     51.390
#  229      69.600
#  11373    34.600
#  10269    54.340
#  1883     69.600
#  7419     63.320
#  11394    59.510
#  8161     46.480
#  4304     19.510
#  571      53.200
#  759      66.617
#  9327     56.708
#  7066     41.070
#  5066     41.660
#  4908     54.620
#  2977     63.330
#  214      61.630
#  5351     43.980
#  2298     63.320
#  1041     63.680
#  6538     32.210
#  3786     44.790
#  11160    36.050
#  10404    84.546
#  11010    55.440
#  10564    45.960
#  166      74.111
#  4958     33.330
#  Name: HourlyRate, dtype: float64>,
#  <bound method Series.mean of 11065    24.8200
#  684      40.3100
#  52       40.0800
#  6172     54.3400
#  1678     73.3100
#  5563     61.8600
#  1185     64.5730
#  5089     34.0500
#  4178     20.7500
#  5452     39.5900
#  11627    69.5630
#  11425    47.3400
#  1413     17.2700
#  8440     45.6800
#  10548    31.8600
#  4833     53.1690
#  9041     88.9260
#  11649    53.6590
#  135      73.3200
#  10032    51.2200
#  2859     45.9600
#  10941    75.2843
#  2070     34.0500
#  4666     38.3200
#  4280     41.0700
#  1899     88.3240
#  2273     65.2520
#  4270     61.0130
#  3777     65.0910
#  2911     64.1600
#  5404     43.9800
#  6523     69.6000
#  1492     25.4600
#  11292    84.5600
#  10669    87.7030
#  6766     63.3200
#  1050     56.2500
#  541      57.8700
#  11623    34.8100
#  2270     55.3400
#  8108     66.7170
#  1755     70.2670
#  499      38.3200
#  9863     61.6390
#  6381     67.2800
#  2970     40.0800
#  9126     63.3300
#  11565    65.6170
#  4011     30.0900
#  708      93.6399
#  Name: HourlyRate, dtype: float64>,
#  <bound method Series.mean of 3706     36.470
#  10806    38.320
#  3037     55.440
#  7693     31.700
#  7459     87.165
#  5914     34.080
#  10160    22.260
#  5472     46.680
#  535      63.467
#  4447     34.810
#  8020     57.440
#  3524     58.220
#  1781     57.550
#  5066     41.660
#  9894     57.870
#  2267     20.280
#  8809     37.860
#  2254     47.340
#  8105     43.490
#  163      55.440
#  8213     29.030
#  2955     56.720
#  3506     46.580
#  8032     54.600
#  449      53.200
#  4774     68.639
#  2951     21.960
#  4408     49.440
#  9340     40.060
#  10986    39.280
#  2196     44.700
#  4137     19.510
#  9179     25.580
#  2878     20.750
#  31       96.460
#  11386    34.810
#  2614     45.810
#  2392     23.140
#  8043     38.000
#  4859     71.760
#  1904     57.087
#  9108     69.070
#  9150     60.580
#  3003     44.090
#  1010     61.141
#  3050     52.530
#  2180     39.700
#  10964    42.570
#  9027     37.980
#  74       63.320
#  Name: HourlyRate, dtype: float64>,
#  <bound method Series.mean of 6057     57.9600
#  1565     47.9600
#  3509     38.6000
#  286      51.7000
#  3047     56.5135
#  10061    39.7000
#  2098     46.6800
#  4802     39.2800
#  10531    48.5900
#  6517     31.3500
#  2512     65.0910
#  3405     42.5700
#  6607     57.3600
#  5965     61.6300
#  8439     18.5600
#  2073     51.3200
#  1552     19.5100
#  7988     51.0700
#  1694     42.4400
#  1222     19.5100
#  9846     51.3600
#  1634     41.1800
#  4451     38.5700
#  4143     47.5100
#  2478     18.5600
#  10194    58.7500
#  9964     39.2800
#  6441     34.0500
#  8649     30.0900
#  4653     48.7800
#  657      56.7260
#  2856     54.4000
#  7977     76.6970
#  9339     20.7500
#  6411     61.8600
#  10340    65.5990
#  8714     23.4000
#  3111     98.7200
#  7095     19.5100
#  4391     62.2610
#  9052     80.0700
#  1707     44.7900
#  10182    43.3400
#  5343     38.0000
#  31       96.4600
#  412      37.9800
#  8159     34.0500
#  10720    61.7980
#  4834     58.5500
#  3765     29.0300
#  Name: HourlyRate, dtype: float64>,
#  <bound method Series.mean of 1513     30.0900
#  3371     45.7500
#  9285     41.8300
#  8322     58.0900
#  4844     18.5600
#  7089     19.5100
#  6558     54.2400
#  9348     69.6000
#  11484    27.1900
#  2200     57.4700
#  4358     71.6899
#  211      66.8400
#  8115     63.5760
#  1943     55.4400
#  8157     31.3500
#  8441     40.8600
#  8133     76.0690
#  8095     55.3200
#  5003     69.4450
#  5046     57.4400
#  4725     35.9100
#  7208     45.9600
#  7900     60.5900
#  8307     57.8845
#  7708     69.5100
#  10378    59.5300
#  4057     36.0500
#  7032     64.8675
#  10514    35.9500
#  2287     64.8950
#  9012     63.9741
#  5636     20.7500
#  5829     18.5600
#  11388    42.5700
#  4893     62.3420
#  7478     69.6000
#  5127     45.7500
#  4138     19.5100
#  8064     47.3400
#  10042    36.6700
#  10807    30.0900
#  6468     35.4600
#  3873     50.0300
#  11671    42.9600
#  7306     84.5600
#  7620     61.8600
#  3103     58.5340
#  4948     69.6000
#  1907     29.0300
#  8534     96.4629
#  Name: HourlyRate, dtype: float64>,
#  <bound method Series.mean of 8990     31.700
#  4938     31.230
#  8838     36.470
#  9017     61.000
#  387      69.600
#  7753     75.510
#  10763    61.860
#  490      55.900
#  4273     46.380
#  804      46.830
#  2187     30.090
#  10224    69.710
#  8475     28.310
#  229      69.600
#  3103     58.534
#  4796     23.650
#  771      39.590
#  330      67.089
#  8501     35.400
#  10142    61.359
#  742      40.860
#  4838     66.404
#  9046     57.230
#  8069     48.990
#  2782     71.760
#  4620     51.320
#  8341     51.180
#  3581     56.310
#  11503    34.470
#  6834     57.870
#  4773     54.110
#  983      30.090
#  5522     60.000
#  3545     57.440
#  8583     20.750
#  6029     36.900
#  4761     66.840
#  586      90.721
#  6256     55.440
#  3363     49.490
#  4976     66.617
#  9021     54.400
#  823      47.740
#  10175    25.550
#  3764     19.510
#  6499     44.950
#  5673     46.680
#  10923    38.290
#  6961     58.861
#  10114    32.850
#  Name: HourlyRate, dtype: float64>,
#  <bound method Series.mean of 8026      53.4500
#  3034      35.4600
#  11169     26.6000
#  5577      35.4600
#  3404      55.4400
#  1528      60.9400
#  4333      19.5100
#  8840      25.5800
#  10332     60.5800
#  7465      17.2700
#  8751      27.0900
#  11625     79.0230
#  8146      51.3900
#  5006      35.4600
#  4888      17.2700
#  3573      67.4230
#  1230      50.0300
#  5991      54.2800
#  8883      56.3300
#  3050      52.5300
#  9839      59.0100
#  5725      33.1400
#  2677      85.9400
#  10774     48.3100
#  7422      25.5800
#  9366      62.6800
#  5326      54.4000
#  10184     62.4178
#  7694      78.0900
#  1013      32.8500
#  2646      64.8900
#  6201      54.6000
#  3487      36.0500
#  7461      60.0000
#  9075      61.3994
#  4522      42.9600
#  6216      62.7800
#  5238      77.0500
#  4944      44.9500
#  5533      19.5100
#  11421     67.5470
#  11391     41.6800
#  6578      55.4400
#  4003      40.0800
#  5410     131.4465
#  1623      55.4400
#  10        33.9400
#  10584     60.2300
#  6513      65.1700
#  6534      53.0300
#  Name: HourlyRate, dtype: float64>,
#  <bound method Series.mean of 10876    18.560
#  9176     57.870
#  6843     61.860
#  5887     19.510
#  8787     37.750
#  9513     25.580
#  7783     48.250
#  3040     41.170
#  6346     59.824
#  6803     54.290
#  2266     51.390
#  9818     36.050
#  10387    55.440
#  5911     61.630
#  4226     38.290
#  7545     51.700
#  11711    21.900
#  11051    33.780
#  2794     59.328
#  134      46.050
#  3975     42.440
#  6322     51.700
#  4085     31.350
#  6562     18.560
#  2662     42.570
#  6784     51.070
#  2579     19.510
#  10534    70.697
#  9987     53.729
#  10874    61.860
#  9796     38.950
#  4688     47.940
#  2785     51.390
#  2461     57.870
#  7834     18.560
#  10866    65.565
#  3580     53.130
#  11277    64.251
#  3011     34.810
#  433      44.790
#  8676     25.580
#  7144     53.435
#  2755     46.680
#  7811     24.920
#  1273     18.560
#  11109    41.660
#  11734    41.450
#  1188     45.960
#  492      55.440
#  10753    29.030
#  Name: HourlyRate, dtype: float64>,
#  <bound method Series.mean of 19       56.5000
#  1105     32.5200
#  3704     34.0500
#  10881    30.0900
#  8148     72.7700
#  6862     39.5900
#  9708     50.0300
#  11018    70.7620
#  4051     55.6698
#  4066     37.3200
#  9766     46.6800
#  7951     26.0500
#  2327     63.3200
#  8939     41.0700
#  5706     32.6000
#  6566     65.7960
#  6407     34.0500
#  10079    39.2800
#  8381     60.8500
#  10834    55.4400
#  6493     39.7000
#  6680     39.7000
#  6903     67.4900
#  8226     44.9500
#  4907     66.3800
#  331      58.2200
#  4701     60.5800
#  223      57.8700
#  942      26.0500
#  437      34.0500
#  6947     39.5900
#  4190     34.2300
#  10002    30.0900
#  3172     57.8700
#  10139    43.7600
#  6540     73.3100
#  5736     51.6860
#  7933     30.0900
#  4725     35.9100
#  8989     28.3100
#  577      45.9600
#  7732     63.1420
#  5190     54.2900
#  3344     63.4720
#  2852     45.9600
#  2066     69.6000
#  1647     34.8100
#  6720     34.0500
#  1295     57.9850
#  9985     31.0200
#  Name: HourlyRate, dtype: float64>,
#  <bound method Series.mean of 5428     43.340
#  1377     19.090
#  3485     51.070
#  786      40.610
#  7267     39.730
#  1153     18.560
#  6290     55.150
#  5851     43.340
#  10082    54.340
#  1729     63.075
#  5874     39.470
#  4362     72.130
#  6641     55.340
#  6006     60.894
#  4018     26.990
#  581      42.570
#  11336    18.560
#  5675     43.340
#  8132     65.829
#  6370     27.190
#  5877     59.550
#  5986     46.380
#  4521     35.050
#  6573     29.030
#  2008     39.590
#  7124     19.510
#  8507     51.320
#  5848     33.440
#  5478     47.690
#  524      30.970
#  5088     62.838
#  5625     43.150
#  6768     45.620
#  10838    23.320
#  6898     53.618
#  10702    38.640
#  3576     58.270
#  7473     93.341
#  3925     27.190
#  2521     40.660
#  9615     77.050
#  2564     50.820
#  2295     46.900
#  10017    60.590
#  3955     48.250
#  8080     45.580
#  2902     33.780
#  4817     43.220
#  7996     60.590
#  2627     48.480
#  Name: HourlyRate, dtype: float64>,
#  <bound method Series.mean of 2999     42.570
#  7422     25.580
#  11288    53.780
#  2794     59.328
#  9479     28.000
#  1847     34.050
#  8846     32.470
#  274      56.800
#  9901     46.680
#  5576     56.250
#  138      30.090
#  2138     47.740
#  5340     61.220
#  5033     47.320
#  8092     32.550
#  11096    62.072
#  3938     33.790
#  3328     70.630
#  9508     34.810
#  4969     35.420
#  11083    57.960
#  8272     74.914
#  2927     51.700
#  6929     60.780
#  4678     55.660
#  10606    41.070
#  3235     67.106
#  9661     61.000
#  7293     41.660
#  586      90.721
#  6120     73.523
#  5782     47.340
#  4705     25.580
#  1545     30.090
#  11011    55.440
#  3100     60.840
#  8827     23.320
#  3269     65.780
#  7307     76.430
#  11224    46.370
#  4476     66.617
#  10445    19.510
#  9790     52.030
#  10793    46.680
#  514      60.060
#  5059     66.090
#  9882     39.730
#  3227     30.090
#  7204     35.950
#  11511    73.000
#  Name: HourlyRate, dtype: float64>,
#  <bound method Series.mean of 3741     29.290
#  5076     66.380
#  330      67.089
#  6570     61.860
#  8889     47.570
#  2148     30.090
#  5397     18.560
#  146      32.210
#  5136     53.020
#  9722     54.400
#  5541     53.500
#  7416     46.680
#  6645     55.340
#  10562    24.110
#  2357     55.440
#  5112     61.860
#  11042    57.870
#  11513    55.340
#  407      54.190
#  394      51.320
#  8996     53.041
#  2610     39.280
#  7660     54.200
#  6540     73.310
#  6044     44.950
#  9809     57.440
#  7173     25.580
#  9783     57.700
#  4909     55.440
#  8039     72.750
#  10803    22.860
#  9366     62.680
#  10268    61.910
#  5822     47.510
#  6875     46.680
#  10959    39.220
#  2009     31.360
#  9985     31.020
#  3298     50.860
#  7879     61.420
#  6983     33.330
#  5874     39.470
#  9619     62.688
#  7259     59.740
#  7342     49.562
#  11032    44.950
#  7325     62.859
#  4744     53.780
#  8607     41.830
#  4625     55.440
#  Name: HourlyRate, dtype: float64>,
#  <bound method Series.mean of 4673     55.0300
#  9923     18.5600
#  6515     50.9696
#  424      67.5900
#  3351     60.5800
#  3784     30.0900
#  10834    55.4400
#  3031     56.8200
#  3025     36.0500
#  3010     34.8100
#  8494     47.4700
#  8486     44.9500
#  5225     54.4000
#  1328     29.0300
#  5430     47.6900
#  3622     61.2850
#  8197     18.9100
#  10536    37.8400
#  392      35.7400
#  9551     36.0500
#  5487     46.4800
#  6778     34.0800
#  3725     47.6600
#  10826    34.0800
#  7130     37.8400
#  1087     62.4700
#  1979     36.0500
#  1604     58.7500
#  11308    59.5119
#  4904     39.6700
#  7074     19.5100
#  10183    25.5800
#  5990     61.6300
#  8211     46.6800
#  4863     31.6000
#  1684     58.7260
#  349      39.2800
#  10301    30.0900
#  2705     19.5100
#  7315     41.6600
#  11044    43.3400
#  1844     67.4900
#  7025     18.5600
#  3772     25.5800
#  7661     62.2300
#  4992     87.6230
#  2308     63.0900
#  4449     34.8100
#  7374     21.9000
#  1332     77.0500
#  Name: HourlyRate, dtype: float64>,
#  <bound method Series.mean of 4487      36.9000
#  6094      49.3400
#  11142     62.6800
#  8956      19.5100
#  776       29.0300
#  5132      36.0500
#  4460      38.0000
#  9037      63.5450
#  10539     34.5800
#  4223      54.8580
#  7628      41.8300
#  2303      54.2900
#  6544      62.3270
#  9426      40.8600
#  8548      53.8230
#  6476      57.8700
#  651       34.0500
#  3265      18.5600
#  9966      49.0990
#  10776     42.4400
#  3171      80.0300
#  668       43.2700
#  6348      46.6800
#  4111      30.0900
#  4985      43.7700
#  2024      55.4400
#  539       92.0370
#  9967      57.1700
#  11040     54.2900
#  839       61.8600
#  5505      38.9500
#  11090     35.9500
#  6424      64.3910
#  10100     43.4900
#  4385      19.0900
#  8067      67.4900
#  5390      55.3400
#  3501     105.0720
#  10660     71.7250
#  743       89.7494
#  8466      54.2900
#  5809      30.0900
#  11413     23.1400
#  996       57.9800
#  1208      23.4000
#  9789      46.6800
#  10020     55.3400
#  1881      73.3100
#  4058      36.0500
#  1011      41.3800
#  Name: HourlyRate, dtype: float64>,
#  <bound method Series.mean of 1386     57.4590
#  10883    63.5900
#  9496     42.9200
#  3051     48.4800
#  4532     38.8600
#  4977     35.7900
#  7090     33.7800
#  3709     81.7335
#  2576     18.5600
#  6079     48.0300
#  8266     42.5700
#  10178    66.1400
#  7043     55.7300
#  7198     31.8600
#  6135     55.3400
#  10019    30.0900
#  834      61.8600
#  11229    30.0900
#  1042     29.0300
#  8771     35.1600
#  2704     25.5800
#  8020     57.4400
#  6024     34.8100
#  1313     19.5100
#  329      55.6600
#  8256     35.9500
#  6700     44.1300
#  7151     49.4900
#  10196    72.0410
#  8798     45.9600
#  10687    60.8400
#  8140     50.4300
#  10629    55.2400
#  7221     45.9600
#  4842     69.1100
#  6858     39.1600
#  10638    62.8960
#  1218     36.3300
#  2332     30.0900
#  52       40.0800
#  8191     18.5600
#  8968     50.1170
#  10905    39.2800
#  2126     63.7420
#  1088     46.4800
#  1290     66.8700
#  5483     52.9290
#  2213     36.4700
#  10559    43.1500
#  5100     48.2500
#  Name: HourlyRate, dtype: float64>,
#  <bound method Series.mean of 3172     57.8700
#  6423     40.0800
#  8444     61.8600
#  11651    30.7300
#  4375     38.8100
#  2920     59.8300
#  8539     42.0500
#  11650    34.4700
#  8667     18.5600
#  7038     56.5281
#  9786     52.4100
#  1651     30.1800
#  8751     27.0900
#  6237     34.6000
#  4144     19.5100
#  11260    65.1570
#  10952    49.4000
#  8207     55.3400
#  7274     35.0500
#  10553    23.6200
#  11372    25.5500
#  6560     39.7000
#  1264     65.9240
#  10795    57.8500
#  8744     56.2800
#  10138    66.7600
#  3713     55.3400
#  3153     40.3700
#  5709     63.5920
#  8538     18.5600
#  11668    34.8100
#  3612     60.5900
#  5837     72.1300
#  11381    39.2800
#  5990     61.6300
#  7877     60.0600
#  8129     34.9400
#  6888     60.2300
#  6363     33.7800
#  1568     42.9200
#  7484     56.8200
#  4853     47.9400
#  7676     31.3500
#  10804    31.3500
#  3588     70.2600
#  5093     57.0780
#  8875     20.6700
#  114      34.4700
#  3809     38.0000
#  3127     86.4430
#  Name: HourlyRate, dtype: float64>,
#  <bound method Series.mean of 484       34.4700
#  10182     43.3400
#  5915      84.5600
#  173       72.1300
#  2426      46.6800
#  10158     41.6600
#  9928      54.6000
#  6164      63.7530
#  3087     110.2200
#  1209      25.5800
#  10689     36.0500
#  3987      30.0900
#  7466      31.8600
#  11430     72.2730
#  3063      69.1840
#  7198      31.8600
#  3184      36.0500
#  11159     74.8200
#  5837      72.1300
#  8962      52.5580
#  7489      55.6600
#  4764      62.3210
#  238       69.6000
#  3196      63.7250
#  9812      34.4700
#  7546     124.1840
#  9419      36.0500
#  7791      37.0900
#  283       73.1500
#  7926      34.0800
#  6218      62.4900
#  5543      19.5100
#  10460     19.5100
#  1668      23.6500
#  3381      89.1160
#  3138      17.2700
#  3319      67.5340
#  2026      36.4700
#  3006      61.8600
#  390       38.0000
#  4555      40.0800
#  8802      38.3100
#  6682      72.7500
#  10766     47.7400
#  11315     23.4000
#  1061      67.8832
#  991       30.9700
#  6253      65.9000
#  5642      56.7529
#  8227      18.5600
#  Name: HourlyRate, dtype: float64>,
#  <bound method Series.mean of 2381     61.8600
#  2975     60.5900
#  8248     55.3400
#  6077     36.0500
#  9362     38.8300
#  1197     67.4900
#  249      83.8100
#  4903     32.2100
#  735      55.6300
#  9079     30.0900
#  3725     47.6600
#  2431     43.4900
#  8599     19.5100
#  11593    57.1700
#  5324     60.9991
#  2138     47.7400
#  2859     45.9600
#  7682     30.0900
#  1734     36.0500
#  11165    51.3200
#  741      58.7800
#  3741     29.2900
#  4577     32.4700
#  8845     29.5400
#  9817     57.8700
#  8481     58.8610
#  7123     70.6120
#  8843     18.5600
#  5050     63.7700
#  784      64.8600
#  1943     55.4400
#  8509     38.8100
#  10659    67.4900
#  9762     34.0800
#  1172     43.9900
#  1029     46.6800
#  2442     68.1960
#  466      65.0910
#  3851     52.4100
#  3517     89.7494
#  8510     37.2900
#  8618     32.5200
#  6470     68.4752
#  10997    28.0000
#  359      55.3480
#  174      36.0500
#  3424     63.5040
#  6199     60.5900
#  9825     54.4000
#  4314     61.6300
#  Name: HourlyRate, dtype: float64>,
#  <bound method Series.mean of 4331     34.8100
#  1383     18.5600
#  10500    31.3500
#  1078     52.5600
#  6012     18.5600
#  10851    30.0900
#  3459     70.6300
#  8140     50.4300
#  1928     47.6600
#  10301    30.0900
#  9145     39.7300
#  6442     39.5900
#  1421     23.1400
#  601      37.3200
#  2056     31.3500
#  3362     36.0500
#  2403     43.2700
#  5508     19.0900
#  3609     30.0900
#  8442     53.0400
#  4038     30.0900
#  4613     29.0300
#  4568     39.7000
#  10216    48.3100
#  7279     21.9600
#  6326     62.1380
#  1403     30.5100
#  10035    57.8700
#  2888     25.4600
#  501      67.4900
#  7953     87.7000
#  10890    43.1500
#  5593     71.0870
#  3664     65.8200
#  9848     47.2000
#  7930     84.6179
#  6898     53.6180
#  6738     77.0500
#  4288     39.5900
#  3128     41.6100
#  6452     39.2800
#  1126     39.2200
#  797      69.4100
#  1654     40.8600
#  1064     67.4230
#  11292    84.5600
#  9354     73.3800
#  6680     39.7000
#  6502     61.8600
#  3242     49.0400
#  Name: HourlyRate, dtype: float64>,
#  <bound method Series.mean of 2080     29.0300
#  2232     66.6780
#  5243     46.6800
#  428      50.8600
#  8065     57.4400
#  9407     17.2700
#  3263     20.7500
#  966      56.3100
#  6137     66.8790
#  4165     27.6000
#  11114    28.0000
#  8626     53.0400
#  5336     43.9800
#  8537     19.6600
#  751      72.7500
#  9511     29.0300
#  6927     54.2900
#  7359     34.4700
#  8129     34.9400
#  8288     50.1700
#  6855     50.0300
#  2286     81.1786
#  7440     34.8100
#  9260     32.6000
#  10531    48.5900
#  11735    33.4400
#  3654     69.6000
#  7573     55.7300
#  9586     48.4800
#  5861     31.3500
#  8364     36.0500
#  10072    30.0900
#  10252    69.7100
#  30       38.9800
#  2487     41.3800
#  10754    56.3900
#  11157    52.5300
#  11675    23.4000
#  8516     48.4800
#  6403     72.5120
#  9743     52.1800
#  8274     43.9800
#  7345     26.9900
#  6284     55.1500
#  3869     34.4700
#  10976    39.2800
#  9456     62.6800
#  6941     44.4000
#  1494     38.9800
#  5967     46.6800
#  Name: HourlyRate, dtype: float64>,
#  <bound method Series.mean of 9111      67.4900
#  853       18.5600
#  2439      53.4500
#  815       41.3800
#  11709     41.6600
#  3746      46.9000
#  2043      71.9560
#  9824      49.7500
#  694       49.4900
#  3554      53.9900
#  496       30.0900
# ...
#  2662     42.570
#  9178     17.270
#  4047     59.535
#  8482     64.453
#  8922     26.990
#  4345     60.840
#  7816     18.560
#  11134    69.600
#  8891     66.350
#  483      38.810
#  8924     32.840
#  8446     39.780
#  10477    37.100
#  5565     43.490
#  10242    72.750
#  3993     24.210
#  230      51.700
#  1154     55.440
#  830      38.070
#  11434    46.680
#  2386     32.550
#  7792     31.350
#  8670     31.860
#  1829     78.122
#  9387     34.810
#  2925     66.282
#  3336     66.617
#  7538     97.970
#  5899     69.600
#  3159     40.790
#  3370     40.660
#  1749     69.040
#  1367     28.310
#  5822     47.510
#  1364     38.290
#  2102     71.790
#  323      34.050
#  4333     19.510
#  2690     58.000
#  Name: HourlyRate, dtype: float64>,
#  <bound method Series.mean of 4939     66.650
#  10193    43.630
#  2805     60.943
#  7730     39.280
#  8439     18.560
#  1673     61.860
#  1931     31.350
#  4905     49.490
#  11119    18.560
#  5182     31.350
#  4727     62.230
#  3350     40.790
#  9797     35.790
#  7781     32.850
#  8738     33.440
#  2672     35.790
#  4008     64.210
#  5204     50.430
#  6966     57.240
#  5125     57.870
#  9147     36.050
#  3031     56.820
#  7223     21.440
#  3193     61.860
#  2589     30.090
#  1757     70.920
#  8296     71.490
#  11458    46.480
#  10533    62.450
#  9080     30.960
#  574      30.090
#  11217    18.560
#  4286     23.400
#  8539     42.050
#  4777     37.100
#  6180     33.330
#  6747     57.870
#  9149     53.360
#  3662     34.050
#  2173     18.560
#  10224    69.710
#  4845     54.600
#  3742     18.560
#  7016     61.717
#  11332    18.560
#  1695     61.936
#  3535     40.790
#  2942     31.350
#  9866     67.900
#  6650     49.490
#  Name: HourlyRate, dtype: float64>,
#  <bound method Series.mean of 9170     69.7100
#  11675    23.4000
#  11574    42.2400
#  1169     70.7830
#  2726     56.5860
#  978      45.6200
#  7507     34.3500
#  7795     69.6000
#  6437     23.6500
#  5737     55.6500
#  313      50.8600
#  1609     43.3400
#  1618     46.6800
#  5803     51.2500
#  6143     41.3800
#  3250     57.8700
#  8764     42.9600
#  11333    30.0900
#  3001     29.7300
#  3736     55.6000
#  9613     57.0000
#  8908     23.6200
#  72       29.0300
#  10075    42.5700
#  5287     52.4900
#  4425     97.7020
#  7862     34.0500
#  6030     19.5100
#  11337    30.0900
#  1290     66.8700
#  4027     26.9900
#  9365     86.6700
#  3744     46.9000
#  11075    34.0500
#  7945     35.4600
#  3055     57.4700
#  9138     38.3100
#  11679    19.0900
#  9020     57.8700
#  5823     64.9900
#  10459    31.3500
#  10371    66.3500
#  3149     58.9900
#  6759     36.0500
#  10740    61.1900
#  497      46.9000
#  6740     25.5500
#  3726     93.1040
#  5963     55.9900
#  8654     49.4038
#  Name: HourlyRate, dtype: float64>,
#  <bound method Series.mean of 11277    64.2510
#  58       38.3700
#  2189     58.2200
#  7366     33.6400
#  1044     30.0900
#  9583     29.0300
#  7454     36.4800
#  3430     72.7500
#  10129    68.3012
#  1430     44.0100
#  4367     26.3300
#  3885     42.6100
#  735      55.6300
#  8733     92.2590
#  5476     77.0500
#  3973     47.6900
#  2007     35.7400
#  6274     57.5500
#  5434     25.4600
#  8682     29.4500
#  8214     39.1200
#  10511    47.6900
#  4521     35.0500
#  10858    57.4400
#  9715     53.0390
#  4204     31.3500
#  6423     40.0800
#  2955     56.7200
#  4845     54.6000
#  1581     24.9200
#  251      51.7000
#  4318     23.4000
#  10158    41.6600
#  2516     47.5700
#  20       36.9000
#  5441     18.5600
#  10125    66.6170
#  1744     55.4400
#  8683     28.0000
#  936      65.7250
#  10073    57.7910
#  10865    60.0600
#  8572     25.5800
#  2681     58.7100
#  10693    74.6420
#  11679    19.0900
#  6550     27.1900
#  8131     58.9759
#  1445     23.4000
#  3113     36.0500
#  Name: HourlyRate, dtype: float64>,
#  <bound method Series.mean of 9253      45.960
#  9383      46.680
#  3586      41.610
#  966       56.310
#  10476     58.550
#  3337      31.350
#  9009      47.510
#  6446      31.700
#  2189      58.220
#  3849      46.060
#  7520      31.350
#  9806      63.576
#  531       40.790
#  8283     135.210
#  11706     38.980
#  9568      53.500
#  3302      75.750
#  9783      57.700
#  10128     46.380
#  5046      57.440
#  7922      38.310
#  7445      44.010
#  9535      54.240
#  9877      46.680
#  7079      17.270
#  4085      31.350
#  5061      50.410
#  3423      45.960
#  11701     19.510
#  4933      60.810
#  10238     46.680
#  11541     65.617
#  2297      37.290
#  2078      27.190
#  11151     49.440
#  1272      25.580
#  31        96.460
#  9901      46.680
#  8353      43.980
#  4196      41.380
#  74        63.320
#  3393      57.700
#  8976      18.560
#  4360     109.160
#  1878      51.380
#  237       65.701
#  8884      77.050
#  2550      35.460
#  9626      38.430
#  8698      34.520
#  Name: HourlyRate, dtype: float64>,
#  <bound method Series.mean of 6252     36.4800
#  5226     55.3400
#  666      53.7400
#  6855     50.0300
#  5404     43.9800
#  8442     53.0400
#  5455     36.3100
#  3183     61.1920
#  2821     27.6000
#  9754     34.0500
#  444      69.1100
#  7269     24.9200
#  7790     67.0890
#  5299     60.5900
#  3534     46.6800
#  9924     90.7890
#  6456     62.2610
#  5627     47.6900
#  1177     49.4400
#  4004     37.1000
#  3865     59.5500
#  3825     74.5000
#  4410     43.3400
#  9466     83.4760
#  4020     67.4900
#  2946     60.8500
#  10141    66.7600
#  3190     38.8600
#  245      59.5600
#  11570    31.3500
#  9320     61.8900
#  5926     60.5694
#  6977     42.4400
#  9562     41.6600
#  460      54.1900
#  2765     72.7791
#  1339     18.5600
#  7414     36.9000
#  7064     18.5600
#  424      67.5900
#  10714    51.0700
#  9640     39.6100
#  7252     79.5360
#  3820     61.8600
#  31       96.4600
#  3465     34.3500
#  10769    61.8600
#  6241     60.5800
#  6510     31.3500
#  6846     19.5100
#  Name: HourlyRate, dtype: float64>,
#  <bound method Series.mean of 1051     44.320
#  10400    22.260
#  2102     71.790
#  8816     51.250
#  5752     66.877
#  10159    77.050
#  696      65.700
#  1290     66.870
#  8672     19.510
#  3214     69.710
#  10851    30.090
#  5705     19.090
#  1800     49.950
#  10101    55.390
#  7035     31.700
#  3022     61.890
#  1567     73.630
#  10943    19.510
#  1920     67.490
#  1230     50.030
#  4588     28.310
#  9825     54.400
#  5508     19.090
#  1040     20.970
#  1698     36.050
#  10843    24.210
#  6672     53.030
#  10592    32.480
#  2690     58.000
#  5887     19.510
#  1816     18.560
#  3377     56.390
#  773      61.297
#  10395    53.200
#  8364     36.050
#  3850     56.870
#  8137     50.680
#  381      61.360
#  11665    40.060
#  8918     43.340
#  111      19.290
#  11319    23.400
#  10773    46.680
#  5984     42.570
#  2035     69.600
#  4442     53.450
#  5251     43.270
#  10269    54.340
#  11687    40.060
#  6464     71.675
#  Name: HourlyRate, dtype: float64>,
#  <bound method Series.mean of 10663     57.4400
#  2950      59.7400
#  7584      75.9400
#  8807      38.5700
#  2885      31.3500
#  10457     25.5800
#  10689     36.0500
#  8214      39.1200
#  4344      83.8100
#  929       51.3900
#  2723      18.5600
#  2109      41.4800
#  11587     92.4586
#  8925      58.7100
#  6175      18.5600
#  1253      30.0900
#  10540     19.5100
#  9095      56.4600
#  10650     57.8700
#  8493      49.4900
#  11718     49.4900
#  8338      63.3200
#  4179      34.1500
#  8260      34.4700
#  3621      43.7700
#  286       51.7000
#  6210      37.2900
#  5076      66.3800
#  3744      46.9000
#  1410      31.3000
#  10277    124.4400
#  631       59.0100
#  7980      56.3900
#  10839     38.0000
#  11515     55.2740
#  10150     32.4800
#  10679      5.5300
#  4029      18.5600
#  9903      18.5600
#  10608     55.9912
#  10500     31.3500
#  4492      18.5600
#  5721      37.3100
#  2824      36.4700
#  3975      42.4400
#  96        54.9650
#  6693      49.4900
#  3559      34.3500
#  4268      24.9200
#  9833      37.2900
#  Name: HourlyRate, dtype: float64>,
#  <bound method Series.mean of 9300      54.1520
#  6718      21.9600
#  8313      57.1700
#  2462      47.3400
#  127       82.4450
#  1815      77.8800
#  11413     23.1400
#  3962      34.4700
#  6163      74.6420
#  2060      54.2100
#  10588     49.4000
#  9113      52.9400
#  5032      44.8200
#  1047      41.6600
#  11496     86.4200
#  3574      42.5700
#  654       56.5600
#  7276      55.3300
#  334       47.9400
#  1798      64.6643
#  6260      47.9600
#  7702      54.6000
#  811       34.0500
#  11020     52.4100
#  8087      25.4600
#  6678      52.3140
#  1506      34.9400
#  9359      18.5600
#  4516      45.6800
#  5530      39.2200
#  8220      49.2400
#  6880      72.7500
#  9452      33.2100
#  7438      35.3500
#  2331     101.5330
#  11409     53.7400
#  6052      74.2400
#  9019      47.9400
#  9626      38.4300
#  2110      53.4500
#  1089      46.0600
#  1705      82.3560
#  838       69.6000
#  5709      63.5920
#  6621      49.4900
#  4808      61.8600
#  7084      33.1400
#  7232      19.5100
#  1666      41.8300
#  5643      17.2700
#  Name: HourlyRate, dtype: float64>,
#  <bound method Series.mean of 1357      25.5800
#  1005      57.4700
#  5771      45.9600
#  9322      33.1400
#  3014      84.0000
#  0         53.7400
#  5180      55.3400
#  270       67.5250
#  3724      51.3200
#  11453    146.5431
#  6368      61.1900
#  11377     32.4700
#  9713      31.3500
#  1099      43.1500
#  10104     34.4700
#  4059      36.0500
#  5366      46.6800
#  2824      36.4700
#  9073      93.1040
#  644       25.5800
#  8992      49.4000
#  4829      36.3100
#  3495      31.3500
#  4004      37.1000
#  8295      66.6170
#  952       36.4700
#  4133      51.2550
#  4138      19.5100
#  9455      57.3800
#  6739      31.0200
#  3141      31.3500
#  11648     36.6400
#  6928      36.3300
#  7399      36.0500
#  188       53.3600
#  7656      62.6800
#  8454      36.3100
#  9843      30.0900
#  1743      41.1700
#  2192      56.2500
#  1114      47.5700
#  4583      44.9500
#  9207      53.0200
#  4909      55.4400
#  4014      39.2800
#  5209      18.5600
#  2760      23.4000
#  9837      63.3200
#  2114      52.4100
#  6751      54.6000
#  Name: HourlyRate, dtype: float64>,
#  <bound method Series.mean of 10960    53.5000
#  7056     39.2800
#  5781     35.4600
#  8199     37.5400
#  4225     57.3800
#  6202     64.3300
#  8691     40.0800
#  4681     55.3020
#  6693     49.4900
#  10408    46.9000
#  2324     64.6540
#  2270     55.3400
#  7240     36.0500
#  1546     39.2200
#  7458     37.1000
#  77       36.0500
#  8958     41.2500
#  1683     61.0090
#  8996     53.0410
#  143      42.9200
#  10823    62.4300
#  873      35.7800
#  10755    61.8600
#  5051     42.5700
#  4374     57.8700
#  9589     31.3500
#  10161    49.7500
#  235      54.6200
#  9467     36.4700
#  8979     24.9200
#  66       18.5600
#  6232     69.7100
#  3581     56.3100
#  7334     55.0000
#  4663     48.7800
#  2054     33.7800
#  10094    66.4578
#  11266    28.3100
#  4608     57.8700
#  6794     31.3500
#  5139     93.1040
#  2107     50.9700
#  7604     62.6800
#  6694     53.2000
#  27       37.1000
#  7237     66.4480
#  7582     46.6800
#  9831     67.7790
#  7072     65.7250
#  6980     51.3400
#  Name: HourlyRate, dtype: float64>,
#  <bound method Series.mean of 6978     31.8600
#  10556    57.5500
#  8977     41.9300
#  4146     30.0900
#  10873    67.6900
#  10901    36.0500
#  10234    20.7500
#  1860     25.5800
#  4566     47.1540
#  10701    53.2000
#  1448     30.0900
#  1043     67.4900
#  3078     77.8800
#  8130     30.0900
#  3758     35.4600
#  3038     49.4900
#  2797     20.7500
#  8737     29.0300
#  2736     60.6138
#  9487     25.5800
#  7745     39.5200
#  8892     29.0300
#  11594    24.9200
#  9809     57.4400
#  9686     62.8900
#  10114    32.8500
#  11485    68.1720
#  11165    51.3200
#  7232     19.5100
#  2067     69.6000
#  439      59.3300
#  6269     52.4100
#  9791     66.0900
#  5193     54.2900
#  8681     18.5600
#  2992     53.2000
#  8890     49.4000
#  10248    31.3500
#  10954    54.2900
#  10439    37.9800
#  3244     61.7490
#  6319     68.5000
#  10257    38.9500
#  3084     60.3100
#  9089     58.2200
#  11060    42.9200
#  3436     74.4630
#  778      48.3100
#  1400     41.1877
#  2520     61.7530
#  Name: HourlyRate, dtype: float64>,
#  <bound method Series.mean of 5084      31.700
#  3426      67.790
#  1825      34.080
#  11585     41.660
#  10691     57.440
#  9944      49.750
#  11214     34.050
#  6663      83.551
#  793       67.490
#  7680      48.400
#  3917      43.340
#  9397      40.860
#  3908      61.510
#  6189      67.590
#  7897      54.190
#  4670      63.320
#  5359      30.090
#  9642      55.630
#  3298      50.860
#  9932      30.480
#  8336      63.320
#  5880      46.680
#  9295      45.203
#  6260      47.960
#  8495      46.680
#  5910      62.410
#  4683      77.050
#  10320     38.810
#  6817      18.560
#  10606     41.070
#  6963      27.460
#  5168      43.980
#  9357      34.600
#  4389      19.090
#  11340     62.450
#  8954      58.780
#  10794     46.680
#  1877      55.440
#  10906     31.350
#  7613     100.893
#  11725     23.400
#  7266      34.470
#  2536      61.110
#  2644      30.090
#  7962      39.280
#  7354      20.750
#  10717     57.870
#  8712      35.050
#  4187      52.029
#  11310     57.020
#  Name: HourlyRate, dtype: float64>,
#  <bound method Series.mean of 1764     57.870
#  4115     41.070
#  7133     42.280
#  4998     48.990
#  3876     55.440
#  4432     34.810
#  9405     66.617
#  3409     61.860
#  5728     49.360
#  10804    31.350
#  1498     44.010
#  9174     56.410
#  2818     25.580
#  2947     71.399
#  9058     43.340
#  9776     51.640
#  9417     56.800
#  2945     18.560
#  2452     55.340
#  2114     52.410
#  1473     19.510
#  4867     47.740
#  5498     64.854
#  3502     57.440
#  10521    43.340
#  4520     19.090
#  3401     18.560
#  9708     50.030
#  1373     45.680
#  10901    36.050
#  1161     45.960
#  151      38.860
#  249      83.810
#  6698     61.573
#  2133     46.200
#  7994     63.060
#  3322     41.380
#  3774     60.590
#  6251     39.280
#  8528     61.104
#  1461     71.840
#  8445     51.390
#  10900    36.050
#  653      78.204
#  8550     30.090
#  7628     41.830
#  9429     40.060
#  2439     53.450
#  3396     51.360
#  6100     72.540
#  Name: HourlyRate, dtype: float64>,
#  <bound method Series.mean of 2488     36.470
#  10977    54.290
#  1147     89.117
#  805      45.960
#  9059     35.260
#  7829     72.770
#  7317     40.080
#  1833     75.639
#  7099     45.960
#  9400     70.000
#  5164     36.310
#  11204    70.630
#  2518     66.350
#  4124     32.970
#  4954     53.200
#  3745     43.980
#  4958     33.330
#  4647     36.310
#  1102     55.730
#  959      18.560
#  2873     46.680
#  6130     67.490
#  1745     74.790
#  3438     47.510
#  9369     82.007
#  7909     18.560
#  10477    37.100
#  10615    35.950
#  9416     60.840
#  6496     54.400
#  7870     61.360
#  2947     71.399
#  459      47.940
#  7740     66.221
#  142      58.360
#  8535     49.490
#  710      56.501
#  6065     63.016
#  2544     31.350
#  4150     67.490
#  1417     19.510
#  11523    69.120
#  2768     27.600
#  8481     58.861
#  11715    52.020
#  1526     19.090
#  8555     39.590
#  964      45.020
#  2224     18.560
#  5055     61.574
#  Name: HourlyRate, dtype: float64>,
#  <bound method Series.mean of 3422     48.480
#  1140     43.340
#  3545     57.440
#  7506     54.400
#  192      54.610
#  1720     31.350
#  11701    19.510
#  10649    30.090
#  4932     34.940
#  3407     57.700
#  3859     43.150
#  2436     59.550
#  6406     25.580
#  9814     58.220
#  2559     53.740
#  10831    40.310
#  2844     19.510
#  10599    29.030
#  6554     32.850
#  6098     72.130
#  6696     30.090
#  10120    24.920
#  4575     43.340
#  5892     41.610
#  9818     36.050
#  9112     50.860
#  9715     53.039
#  8744     56.280
#  6494     50.430
#  9636     53.087
#  3679     26.050
#  1469     45.750
#  1331     23.400
#  8812     19.090
#  10784    74.463
#  4991     41.380
#  11720    19.510
#  9374     37.320
#  3710     52.367
#  6537     35.050
#  9863     61.639
#  4804     42.380
#  6739     31.020
#  7773     63.056
#  3306     58.750
#  2508     63.320
#  3374     52.940
#  6797     55.182
#  10291    50.860
#  4388     19.090
#  Name: HourlyRate, dtype: float64>,
#  <bound method Series.mean of 6351     67.590
#  3126     65.170
#  9583     29.030
#  9456     62.680
#  4121     62.209
#  8564     32.230
#  5704     19.510
#  7226     43.150
#  8874     17.270
#  4486     35.050
#  2055     44.720
#  6036     60.810
#  10747    41.610
#  3130     67.195
#  4379     61.390
#  4489     23.400
#  10683    59.550
#  11298    84.570
#  4874     67.480
#  11387    34.810
#  3932     39.280
#  3880     47.480
#  6212     30.090
#  5651     23.400
#  11677    24.110
#  547      61.420
#  1967     53.360
#  5045     37.840
#  8983     44.000
#  11614    34.810
#  3442     67.489
#  8047     53.450
#  5108     57.440
#  1581     24.920
#  10799    59.010
#  10852    61.860
#  1920     67.490
#  4387     44.090
#  5568     40.120
#  3654     69.600
#  7963     61.860
#  6925     66.350
#  10401    38.830
#  546      30.090
#  8576     31.350
#  100      84.560
#  8300     69.840
#  7806     58.990
#  3377     56.390
#  4299     53.500
#  Name: HourlyRate, dtype: float64>]

# %% [markdown]
# <details>
#     <summary>Answer</summary>
#
# ```python
# sample_means = [df.HourlyRate.sample(n).mean() for x in range(k)]
# ```
# </details>

# %%
# Plotting the distribution of our samples, plus our pop and sample means
pop_mean = df['HourlyRate'].mean()
samp_mean = np.mean(sample_means)

plt.figure(figsize=(8,6))

sns.histplot(sample_means)

plt.vlines(pop_mean, ymin=0, ymax=25, color='r', linestyle=':',
           label=f'Population Mean: {pop_mean:.2f}')
plt.vlines(samp_mean, ymin=0, ymax=25, color='g', linestyle=':',
           label=f'Mean of {k} Samples: {samp_mean:.2f}')

plt.legend();
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 3
#       1 # Plotting the distribution of our samples, plus our pop and sample means
#       2 pop_mean = df['HourlyRate'].mean()
# ----> 3 samp_mean = np.mean(sample_means)
#       5 plt.figure(figsize=(8,6))
#       7 sns.histplot(sample_means)
#
# File ~/anaconda3/envs/learn-env/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3504, in mean(a, axis, dtype, out, keepdims, where)
#    3501     else:
#    3502         return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# -> 3504 return _methods._mean(a, axis=axis, dtype=dtype,
#    3505                       out=out, **kwargs)
#
# File ~/anaconda3/envs/learn-env/lib/python3.11/site-packages/numpy/core/_methods.py:118, in _mean(a, axis, dtype, out, keepdims, where)
#     115         dtype = mu.dtype('f4')
#     116         is_float16_result = True
# --> 118 ret = umr_sum(arr, axis, dtype, out, keepdims, where=where)
#     119 if isinstance(ret, mu.ndarray):
#     120     with _no_nep50_warning():
#
# TypeError: unsupported operand type(s) for +: 'method' and 'method'

# %% [markdown]
# # Level Up: Other Distributions

# %% [markdown]
# The world is full of distributions to explore! See some other less-common ones below:

# %% [markdown]
# ![](images/distributions.png)

# %% [markdown]
# ## Level Up: SKLearn's Standard Scaler
#
# Soon we'll be using a pre-built function to scale our data: https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html
#
# Let's go ahead and peek at our first `sklearn` class!

# %%
# Importing StandardScaler from the preprocessing module
from sklearn.preprocessing import StandardScaler

# Need to instantiate our scaler
scaler = StandardScaler()

# Fitting our scaler (note how we need to make the column into a dataframe)
scaler.fit(df[['HourlyRate']])

# Grabbing the transformed values out as scaled_rate
scaled_rate = scaler.transform(df[['HourlyRate']])

# %%
# Plot and compare results
fig, (ax1, ax2, ax3) = plt.subplots(nrows=3, ncols=1, figsize=(10,6))

sns.kdeplot(df['HourlyRate'], ax=ax1, label='Without Scaling')
ax1.legend()

sns.kdeplot(standardized_rate, ax=ax2, label='Manual Scaling')
ax2.legend()

sns.kdeplot(scaled_rate[:,0], ax=ax3, label='SKLearn Standard Scaling')
ax3.legend()

plt.show()
# Out:
# /Users/rebekahmclaughlin/anaconda3/envs/learn-env/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/rebekahmclaughlin/anaconda3/envs/learn-env/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/rebekahmclaughlin/anaconda3/envs/learn-env/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
